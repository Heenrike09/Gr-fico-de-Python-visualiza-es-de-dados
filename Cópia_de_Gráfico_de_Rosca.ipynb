# %% [markdown]
# <a href="https://colab.research.google.com/github/Heenrike09/Gr-fico-de-Python-visualiza-es-de-dados/blob/main/C%C3%B3pia_de_Gr%C3%A1fico_de_Rosca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Desenolendo Gráficos de Rosca
# Data 09/04/2023 - autor- José Heenrike
# Tarefa da diciplina : visualização de dados#

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
labels = ["Grupo 1","Grupo 2","Grupo 3","Grupo 4","Grupo 5"]

# %%
valores = [10,45,32,56,23]

# %%
cores = ['red','green','blue','orange','cyan']

# %%
raio = 0.7

# %%
plt.pie(valores,labels=labels,colors=cores)
circulo = plt.Circle((0,0),raio,color='white')
p = plt.gcf()
p.gca().add_artist(circulo)
plt.show()

# %%
plt.pie(valores,labels=labels,colors=cores,autopct='%1.1f%%')
circulo = plt.Circle((0,0),raio,color='white')
p = plt.gcf()
p.gca().add_artist(circulo)
plt.show()
